# %%
with open("openpetitions_inbearbeitung_commentundbeschreibung/openpetitions_inbearbeitung_commentundbeschreibung.txt","r",errors='replace') as f:
    lines = f.read().splitlines()

# %%
keyword_list = ['Asyl','asyl','Flucht','flucht','Flücht','flücht','fliehen','Fliehen','Geflohen','geflohen','Refugee','displaced','Displaced','Schutzberechtigt','schutzberechtigt','schutzsuchend','Schutzsuchend','Resettlement',
               'subsidiär','Subsidiär','migra','Migra','migrier','Einwander','einwander','Zuwander','zuwander','Auswander','auswander','zugewandert','Zugewandert','eingewandert','Eingewandert',
               'Ausgewandert','ausgewandert','Ausländer','Aussied','aussied','Sudetendeutsche','Volksdeutsche','Vertriebene','vertriebene',
               'Zwangsarbeit','Gastarbeit','Fremdarbeit','Anwerbe','Saisonarbeit','Russlanddeutsch','russlanddeutsch','Familienzusammenführung','Unbegleitete','unbegleitete',
               'Staatsangehörig','staatsangehörig','Staatenlos','staatenlos','Einbürgerung','Aufenthalts','Bleiberecht','Integration','integration','assimil','Assimil','Freizügigkeit','freizügigkeit',
               'Aufnahme','aufnahme','Abschiebung','abschiebung','Rückführung','rückführung','Ausweisung','ausweisung','Islam','islam','Muslim','muslim','Jesid','jesid','Schengen','Dublin','UNHCR','UNRRA','UNRWA','IRO']

# %%
a='ein IRO'
if any(word in a for word in keyword_list):
    print ('found one of em')
# Out:
# found one of em

# %%
c=0
titel_pos=[]
for i in lines:
    c=c+1
    if 'Titel der Petition:' in i:
        #c=c+1
        titel_pos.append(c)
        print(i.split()[0])
# Out:
# Titel
# Titel
# Titel
# Titel
# Titel
# Titel
# Titel
# Titel
# Titel
# Titel
# Titel
# Titel
# Titel
# Titel
# Titel
# Titel
# Titel
# Titel
# Titel
# Titel
# Titel
# Titel
# Titel
# Titel
# Titel
# Titel
# Titel
# Titel
# Titel
# Titel
# Titel
# Titel
# Titel
# Titel
# Titel
# Titel
# Titel
# Titel
# Titel
# Titel
# Titel
# Titel
# Titel
# Titel
# Titel
# Titel
# Titel
# Titel
# Titel
# Titel
# Titel
# Titel
# Titel
# Titel
# Titel
# Titel
# Titel
# Titel
# Titel
# Titel
# Titel
# Titel
# Titel
# Titel
# Titel
# Titel
# Titel
# Titel
# Titel
# Titel
# Titel
# Titel
# Titel
# Titel
# Titel
# Titel
# Titel
# Titel
# Titel
# Titel
# Titel
# Titel
# Titel
# Titel
# Titel
# Titel
# Titel
# Titel
# Titel
# Titel
# Titel
# Titel
# Titel
# Titel
# Titel
# Titel
# Titel
# Titel
# Titel
# Titel
# Titel
# Titel
# Titel
# Titel
# Titel
# Titel
# Titel
# Titel
# Titel
# Titel
# Titel
# Titel
# Titel
# Titel
# Titel
# Titel
# Titel
# Titel
# Titel
# Titel
# Titel
# Titel
# Titel
# Titel
# Titel
# ...

# %%
len(titel_pos)
# Out:
# 4523

# %%
titel_pos
# Out:
# [1,
#  750093,
#  1756607,
#  2507066,
#  2507083,
#  2918616,
#  3019271,
#  3429649,
#  3621090,
#  3902320,
#  4084617,
#  4084634,
#  4373831,
#  4622028,
#  4809998,
#  4859925,
#  5036917,
#  5036934,
#  5114617,
#  5214942,
#  5214964,
#  5214981,
#  5214998,
#  5368166,
#  5368183,
#  5368200,
#  5368217,
#  5368234,
#  5368251,
#  5368268,
#  5368285,
#  5368302,
#  5583721,
#  5722050,
#  5893753,
#  5978699,
#  6101070,
#  6180066,
#  6213805,
#  6295579,
#  6367608,
#  6448894,
#  6567262,
#  6567279,
#  6567296,
#  6668031,
#  6720980,
#  6803809,
#  6877480,
#  6936011,
#  6936028,
#  7024648,
#  7066942,
#  7150829,
#  7150846,
#  7176699,
#  7211092,
#  7280353,
#  7357641,
#  7391094,
#  7436865,
#  7465317,
#  7504052,
#  7523604,
#  7592344,
#  7592361,
#  7604603,
#  7634611,
#  7684941,
#  7731073,
#  7746185,
#  7790628,
#  7836603,
#  7872968,
#  7928364,
#  7940458,
#  7966148,
#  8007467,
#  8027540,
#  8027557,
#  8033299,
#  8073712,
#  8133081,
# ...

# %%
list_l=[]
for l in lines:
    list_l.append(l)

# %%
def check_solidaritat(a,b):
    c=-999
    l1=list_l[a,b]
    for line in l1:
        if '--------------------------------------------------' in line:
            list_l.index(line)

# %%
check_solidaritat(1,750092)
